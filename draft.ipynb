# %% [markdown]
# # TSETMC

# %% [markdown]
# ## Market Watch

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
url = "https://old.tsetmc.com/tsev2/data/MarketWatchInit.aspx?h=0&r=0"

response = requests.get(url)

# %%
market_watch = BeautifulSoup(response.content).text

# %%
len(market_watch.split("@"))
# Out:
# 5

# %%
market_watch.split("@")[0].split(",")
# Out:
# ['164389', '1183081', '668953']

# %%
market_watch.split("@")[1].split(",")
# Out:
# ['02/8/28 13:49:42',
#  'P',
#  '2026262.40',
#  '(2316.64) -0.11%',
#  '70359083527883136.00',
#  '7681452598.00',
#  '50599699246596.00',
#  '309174',
#  'P',
#  '4822339088.00',
#  '110968560436295.00',
#  '215762',
#  'P',
#  '516947337.00',
#  '1017766121480.00',
#  '36492',
#  '']

# %%
df = pd.Series(market_watch.split("@")[2].split(";")).apply(
    lambda c: pd.Series(c.split(","))
)

# %%
filt = df[2].str.contains("اراد")
df.loc[filt]
# Out:
#                      0             1         2   \
# 430   55938991037260979  IRB4SG6903A2   اراد692
# 446   39633075506333957  IRB4SO130441   اراد112
# 459   21066721937819577  IRB4O03404B1   اراد132
# 497   42066300469778371  IRB4O0350541   اراد133
# 587   21294020791802550  IRB4O0290461   اراد127
# 621    8897331139163152  IRB4SO090621   اراد108
# 639   44883820260298236  IRB4O0290464  اراد1274
# 700   29990078640171531  IRB4SO1202A1   اراد111
# 804   66381814486859895  IRB4SG870334   اراد874
# 877   24341706282853627  IRB4SG330332   اراد332
# 886   41997809087904044  IRB4SG7103B1    اراد71
# 916   20610153643209375  IRB4O0310351   اراد129
# 995   29963964834392911  IRB4SG2402C1    اراد24
# 999   43481364033628101  IRB4O02803C4  اراد1264
# 1035  52909696671667929  IRB4SG960341    اراد96
# 1098  71479348014961494  IRB4SO0102B1   اراد100
# 1174  22067354885788211  IRB4SO170661   اراد116
# 1183  23257748575526845  IRB4SG7203B1    اراد72
# 1242  40348118513018291  IRB4SG500321    اراد50
# 1257  44263351699841112  IRB4O0230382  اراد1222
# 1304  68429446337737591  IRB4SG870331    اراد87
# 1412  32425362809965324  IRB4O0360391   اراد134
# 1466  51576264644235785  IRB4SO200684  اراد1194
# 1535   9075805849723903  IRB4SO060351   اراد105
# 1716  64536596666647539  IRB4SG900521    اراد90
# 1784  35385722970552859  IRB4SO210444  اراد1204
# 1850  69192306313524921  IRB4SO160661   اراد115
#
#                                   3       4       5        6        7  8   \
# 430        مرابحه عام دولت69-ش.خ0310   61041       0   929200   929200  0
# 446    مرابحه عام دولت112-ش.خ 040408   61041       0  1000000  1000000  0
# 459     مرابحه عام دولت132-ش.خ041110   61040       0   943960   943960  0
# 497     مرابحه عام دولت133-ش.خ050410   61040       0   929250   929250  0
# 587     مرابحه عام دولت127-ش.خ040623   61040       0   999830   999830  0
# 1098         0  ...  1  195  2  69  1030530.00  932390.00   50000000  706
# 1174         0  ...  1  169  2  69   861000.00  779000.00   25000000  706
# 1183         0  ...  1  189  2  69  1036740.00  938020.00    8000000  706
# 1242         0  ...  1  166  2  69  1049980.00  950000.00   20000000  706
# 1257         0  ...  1   76  2  69  1004470.00  908810.00   42000000  706
# 1304         0  ...  1  165  2  69  1012480.00  916060.00  100000000  706
# 1412         0  ...  1  132  2  69  1022980.00  925560.00   50000000  706
# 1466   3500000  ...  1    6  2  69  1917900.00       1.00   15000000  706
# 1535         0  ...  1  180  2  69  1028680.00  930720.00   50000000  706
# 1716         0  ...  1  195  2  69   986980.00  893000.00   30000000  706
# 1784  24921791  ...  1   24  2  69  1858000.00       1.00   50000000  706
# 1850         0  ...  1  177  2  69   955500.00  864500.00   30000000  706
#
#      24
# 430
# 446
# 459
# 497
# 587
# 621
# 639
# 700
# 804
# 877
# 886
# 916
# 995
# 999
# 1035
# 1098
# 1174
# 1183
# 1242
# 1257
# 1304
# 1412
# 1466
# 1535
# 1716
# 1784
# 1850
#
# [27 rows x 25 columns]

# %%
pd.Series(market_watch.split("@")[3].split(";")).apply(
    lambda c: pd.Series(c.split(","))
)
# Out:
#                       0  1  2  3       4        5     6      7
# 0        87157161168095  1  1  0       0       50     0     29
# 1       114312662654155  1  4  1    4950     4970  1050   8859
# 2       204092872752957  1  1  1   36950    37550   136   5725
# 3       212813030943790  1  1  1  990000  1000000  2500   2500
# 4       270972009748578  1  1  0       0     2018     0      1
# ...                 ... .. .. ..     ...      ...   ...    ...
# 8761  23592632489955411  1  0  0       0        0     0      0
# 8762  23600798892801694  1  1  1    8520     8580  4862  67337
# 8763  23628030459637463  1  0  1    2369        0    33      0
# 8764  23669004423443369  1  0  1       1        0    11      0
# 8765  23709531360597343  1  0  1     100        0    30      0
#
# [8766 rows x 8 columns]

# %%
market_watch.split("@")[4]
# Out:
# '12370968744'

# %% [markdown]
# ## Datareader

# %%
from smdir.tsetmc import datareader

datareader.search("اراد142")
# Out:
#             insCode2           insCode3           insCode4            insCode  \
# 0  50598644317850899  71073665530007809  47519995126223215  71073665530007809
#
#                          lVal30 lVal18AFC  flow cIsin  zTitad  baseVol  \
# 0  مرابحه عام دولت142-ش.خ031009   اراد142     2  None     0.0        0
#
#   instrumentID cgrValCot cComVal  lastDate  sourceID      flowTitle  \
# 0         None        17    None         1         2  بازار فرابورس
#
#   cgrValCotTitle
# 0             -'

# %% [markdown]
# # IFB

# %% [markdown]
# ## List

# %%
from smdir.metadata_reader import tables
from smdir.ifb import datareader
import pandas as pd

# %%
datareader.update_bond_page()

# %%
pd.read_parquet(tables.ifb.bond_list)
# Out:
#      record_id  document_id  row       symbol publication_volume  \
# 0        32192         3846    1  افق معادن07            2500000
# 1        32177         3843    2      اراد142           50000000
# 2        32180         3845    3      اراد143           70000000
# 3        32161         3841    4      پرشیا06            1500000
# 4        32157         3840    5      اراد141           50000000
# ..         ...          ...  ...          ...                ...
# 697      23436          262  152        اشاد8            2459926
# 698      23432          261  153        اشاد7            3089457
# 699      23428          259  154        اشاد6           23953289
# 700      23424          269  155        اشاد5            9360739
# 701      23416          265  156        اشاد3            8899899
#
#     acceptance_volume nominal_amount_per_note nominal_interest_rate  \
# 0             2500000                 1000000                   23%
# 1            50000000                 1000000                   20%
# 2            70000000                 1000000                   20%
# 3             1500000                 1000000                   23%
# 4            50000000                 1000000                   20%
# ..                ...                     ...                   ...
# 697           2459926                 1000000                  ثابت
# 698           3089457                 1000000                  ثابت
# 699          23953289                 1000000                  ثابت
# 700           9360739                 1000000                  ثابت
# 701           8899899                 1000000                  ثابت
#
#     publication_date                                  market_maker_name  \
# 0         1402-08-17  صندوق سرمایه‌گذاری اختصاصی بازارگردانی آرمان ا...
# 1         1402-08-09                                    فاقد بازارگردان
# 2         1402-08-09                                    فاقد بازارگردان
# 3         1402-08-07                 شرکت تامین سرمایه نوین (سهامی عام)
# 4         1402-08-02                                    فاقد بازارگردان
# ..               ...                                                ...
# 697       1395-04-31                                    فاقد بازارگردان
# 698       1394-12-27                                    فاقد بازارگردان
# 699       1394-12-01                                    فاقد بازارگردان
# 700       1394-09-22                                    فاقد بازارگردان
# 701       1394-07-13                                    فاقد بازارگردان
#
#     market_making_method fluctuation_range documents_and_records description  \
# 0          مبتنی بر حراج              None                  None        None
# 1                   None              None                  None        None
# 2                   None              None                  None        None
# 3          مبتنی بر حراج              None                  None        None
# 4                   None              None                  None        None
# ..                   ...               ...                   ...         ...
# 697                 None              None                  None        None
# 698                 None              None                  None        None
# 699                 None              None                  None        None
# 700                 None              None                  None        None
# 701                 None              None                  None        None
#
#                  received_time
# 0   2023-11-20 17:19:35.039062
# 1   2023-11-20 17:19:35.039062
# 2   2023-11-20 17:19:35.039062
# 3   2023-11-20 17:19:35.039062
# 4   2023-11-20 17:19:35.039062
# ..                         ...
# 697 2023-11-20 17:19:35.039062
# 698 2023-11-20 17:19:35.039062
# 699 2023-11-20 17:19:35.039062
# 700 2023-11-20 17:19:35.039062
# 701 2023-11-20 17:19:35.039062
#
# [702 rows x 15 columns]

# %% [markdown]
# # General

# %% [markdown]
# ## Metadata

# %%
from smdir.metadata_reader import lib_settings

lib_settings.data_dir.parts
# Out:
# ('D:\\', 'SMDIR', 'Data')

# %% [markdown]
# ## Maintainer

# %%
from smdir.maintainer import update_files

update_files()

# %% [markdown]
# ## PyArrow

# %%
import pyarrow

pyarrow.Table
# Out:
# pyarrow.lib.Table
